# %%
# 중간저장용 코드
import requests
import pandas as pd
import time
import os

# 🔐 API 키 불러오기
with open("tmdb_key.txt", "r") as f:
    API_KEY = f.read().strip()

BASE_URL = 'https://api.themoviedb.org/3'
DRAMA_GENRE_ID = 18

# 대상 국가 및 연도
target_countries = {
    'South Korea': 'KR',
    'United States': 'US',
    'United Kingdom': 'GB',
    'Japan': 'JP'
}
years = list(range(2020, 2025))

# 중복 방지용 ID 모음
seen_ids = set()

# 저장할 파일명
output_file = "top20_tv_dramas_ko_2020_2024.csv"

def get_top_tv_shows(country_code, year):
    url = f"{BASE_URL}/discover/tv"
    params = {
        'api_key': API_KEY,
        'language': 'ko-KR',
        'sort_by': 'popularity.desc',
        'with_original_country': country_code,
        'first_air_date_year': year,
        'page': 1
    }

    shows = []
    while len(shows) < 20:
        response = requests.get(url, params=params)
        data = response.json()

        if 'results' not in data or not data['results']:
            break

        for item in data['results']:
            if len(shows) >= 20:
                break
            if DRAMA_GENRE_ID not in item.get('genre_ids', []):
                continue

            tv_id = item['id']
            if tv_id in seen_ids:
                continue

            details = get_tv_details(tv_id, country_code)
            if details:
                shows.append(details)
                seen_ids.add(tv_id)

        params['page'] += 1
        time.sleep(0.25)

    if len(shows) < 20:
        print(f"⚠️ {country_code} {year}: {len(shows)}편만 수집됨")
    return shows

def get_tv_details(tv_id, country_code):
    url = f"{BASE_URL}/tv/{tv_id}"
    params = {'api_key': API_KEY, 'language': 'ko-KR'}
    res = requests.get(url, params=params).json()

    production_countries = [c['iso_3166_1'] for c in res.get('production_countries', [])]
    if country_code not in production_countries:
        return None

    return {
        'tmdb_id': tv_id,
        '제목': res.get('name'),
        '줄거리': res.get('overview'),
        '인기도': res.get('popularity'),
        '평점': res.get('vote_average'),
        '투표수': res.get('vote_count'),
        '시청등급': get_content_rating(tv_id, country_code),
        '방영연도': res.get('first_air_date', '')[:4],
        '제작국가': country_code
    }

def get_content_rating(tv_id, country_code):
    url = f"{BASE_URL}/tv/{tv_id}/content_ratings"
    params = {'api_key': API_KEY}
    res = requests.get(url, params=params).json()
    for entry in res.get('results', []):
        if entry.get('iso_3166_1') == country_code:
            return entry.get('rating')
    return None

# ✅ 수집 및 중간 저장 루프
for country_name, country_code in target_countries.items():
    for year in years:
        print(f"📺 수집 중: {country_name} - {year}")
        top_shows = get_top_tv_shows(country_code, year)

        if not top_shows:
            continue

        temp_df = pd.DataFrame(top_shows)

        if os.path.exists(output_file):
            temp_df.to_csv(output_file, mode='a', header=False, index=False, encoding="utf-8-sig")
        else:
            temp_df.to_csv(output_file, index=False, encoding="utf-8-sig")
# 중간 저장 시 파일이 이미 있으면 헤더 생략
if os.path.exists(output_file):
    temp_df.to_csv(output_file, mode='a', header=False, index=False, encoding="utf-8-sig")
else:
    temp_df.to_csv(output_file, index=False, encoding="utf-8-sig")

print("✅ 전체 수집 완료! 결과 파일:", output_file)
# Out:
# 📺 수집 중: South Korea - 2020
# 📺 수집 중: South Korea - 2021
# 📺 수집 중: South Korea - 2022
# 📺 수집 중: South Korea - 2023
# 📺 수집 중: South Korea - 2024
# 📺 수집 중: United States - 2020
# 📺 수집 중: United States - 2021
# 📺 수집 중: United States - 2022
# 📺 수집 중: United States - 2023
# 📺 수집 중: United States - 2024
# 📺 수집 중: United Kingdom - 2020
# 📺 수집 중: United Kingdom - 2021
# 📺 수집 중: United Kingdom - 2022
# 📺 수집 중: United Kingdom - 2023
# 📺 수집 중: United Kingdom - 2024
# 📺 수집 중: Japan - 2020
# 📺 수집 중: Japan - 2021
# 📺 수집 중: Japan - 2022
# 📺 수집 중: Japan - 2023
# 📺 수집 중: Japan - 2024
# ✅ 전체 수집 완료! 결과 파일: top20_tv_dramas_ko_2020_2024.csv

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/soyoun/Downloads/translate-key.json"

# %%
# OMDB 줄거리 통합 후에 구글 클라우드 api로 번역
# !pip install google-cloud-translate

import pandas as pd
import requests
import os
import time
from google.cloud import translate_v2 as translate

# 🔐 API 키 불러오기
with open("tmdb_key.txt") as f: tmdb_key = f.read().strip()
with open("omdb_key.txt") as f: omdb_key = f.read().strip()

# 🔐 Google 인증 키 환경변수 등록
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/soyoun/Downloads/translate-key.json"

# ✅ 번역 클라이언트
gcp_translate_client = translate.Client()

# ✅ 함수 1: TMDB ID → IMDb ID
def get_imdb_id(tmdb_id):
    try:
        url = f"https://api.themoviedb.org/3/tv/{tmdb_id}/external_ids"
        res = requests.get(url, params={"api_key": tmdb_key})
        return res.json().get("imdb_id")
    except:
        return None

# ✅ 함수 2: IMDb ID → OMDb 영어 줄거리
def get_omdb_plot(imdb_id):
    try:
        url = f"http://www.omdbapi.com/?apikey={omdb_key}&i={imdb_id}&plot=full"
        res = requests.get(url)
        return res.json().get("Plot")
    except:
        return None

# ✅ 함수 3: 영어 → 한글 번역
def translate_to_korean(text):
    try:
        if not text: return None
        result = gcp_translate_client.translate(text, target_language='ko')
        return result['translatedText']
    except:
        return None

# ✅ 데이터 불러오기
df = pd.read_csv("top20_tv_dramas_ko_2020_2024.csv")
df["imdb_id"] = None
df["omdb_plot_en"] = None
df["omdb_plot_ko"] = None

# ✅ 전체 처리 루프
for i, row in df.iterrows():
    tmdb_id = row["tmdb_id"]

    imdb_id = get_imdb_id(tmdb_id)
    plot_en = get_omdb_plot(imdb_id)
    plot_ko = translate_to_korean(plot_en)

    df.at[i, "imdb_id"] = imdb_id
    df.at[i, "omdb_plot_en"] = plot_en
    df.at[i, "omdb_plot_ko"] = plot_ko

    print(f"🎬 {i+1}/{len(df)} - {row['제목']} 완료")
    time.sleep(1.2)  # API 호출 제한 보호

# ✅ 결과 저장
df.to_csv("translated_dramas.csv", index=False, encoding="utf-8-sig")
print("✅ 번역 완료: translated_dramas.csv 저장됨")
# Out:
# Requirement already satisfied: google-cloud-translate in c:\anaconda\lib\site-packages (3.20.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (2.25.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\anaconda\lib\site-packages (from google-cloud-translate) (2.40.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in c:\anaconda\lib\site-packages (from google-cloud-translate) (2.4.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\anaconda\lib\site-packages (from google-cloud-translate) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\anaconda\lib\site-packages (from google-cloud-translate) (6.31.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\anaconda\lib\site-packages (from google-cloud-translate) (0.14.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (1.72.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (1.72.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (4.9.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-translate) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-translate) (2025.4.26)
# 🎬 1/420 - 여신강림 완료
# 🎬 2/420 - 18 어게인 완료
# 🎬 3/420 - 경이로운 소문 완료
# 🎬 4/420 - 브람스를 좋아하세요 완료
# 🎬 5/420 - 이태원 클라쓰 완료
# 🎬 6/420 - 아무도 모른다 완료
# 🎬 7/420 - 구미호뎐 완료
# 🎬 8/420 - 위험한 약속 완료
# 🎬 9/420 - 설국열차 완료
# 🎬 10/420 - 사이코지만 괜찮아 완료
# 🎬 11/420 - 펜트하우스 완료
# 🎬 12/420 - 편의점 샛별이 완료
# 🎬 13/420 - 우리, 사랑했을까 완료
# 🎬 14/420 - 좀비탐정 완료
# 🎬 15/420 - 슬기로운 의사생활 완료
# 🎬 16/420 - 철인왕후 완료
# 🎬 17/420 - 반의반 완료
# 🎬 18/420 - 기막힌 유산 완료
# 🎬 19/420 - 암행어사: 조선비밀수사단 완료
# 🎬 20/420 - 한 번 다녀왔습니다 완료
# 🎬 21/420 - 오징어 게임 완료
# 🎬 22/420 - 모범택시 완료
# 🎬 23/420 - 달리와 감자탕 완료
# 🎬 24/420 - 해피니스 완료
# 🎬 25/420 - 그 해 우리는 완료
# 🎬 26/420 - 구경이 완료
# 🎬 27/420 - 어느 날 완료
# 🎬 28/420 - 빈센조 완료
# 🎬 29/420 - 오월의 청춘 완료
# 🎬 30/420 - 지금, 헤어지는 중입니다 완료
# 🎬 31/420 - 연모 완료
# 🎬 32/420 - 안녕? 나야! 완료
# 🎬 33/420 - 미치지 않고서야 완료
# 🎬 34/420 - 마이 네임 완료
# 🎬 35/420 - 대박부동산 완료
# 🎬 36/420 - 더 로드: 1의 비극 완료
# 🎬 37/420 - 마녀식당으로 오세요 완료
# 🎬 38/420 - 갯마을 차차차 완료
# 🎬 39/420 - 라켓소년단 완료
# 🎬 40/420 - 어느 날 우리 집 현관으로 멸망이 들어왔다 완료
# 🎬 41/420 - 약한영웅 완료
# 🎬 42/420 - 으라차차 내 인생 완료
# 🎬 43/420 - 지금 우리 학교는 완료
# 🎬 44/420 - 3인칭 복수 완료
# 🎬 45/420 - Flower of Evil 완료
# 🎬 46/420 - 커튼콜: 나무는 서서 죽는다 완료
# 🎬 47/420 - 환혼 완료
# 🎬 48/420 - 안나라수마나라 완료
# 🎬 49/420 - 사내맞선 완료
# 🎬 50/420 - 현재는 아름다워 완료
# 🎬 51/420 - 재벌집 막내아들 완료
# 🎬 52/420 - 미남당 완료
# 🎬 53/420 - 왜 오수재인가 완료
# 🎬 54/420 - 빅마우스 완료
# 🎬 55/420 - 안나 완료
# 🎬 56/420 - 더 글로리 완료
# 🎬 57/420 - 소방서 옆 경찰서 완료
# 🎬 58/420 - 오늘의 웹툰 완료
# 🎬 59/420 - 구필수는 없다 완료
# 🎬 60/420 - 모범가족 완료
# 🎬 61/420 - 하늘의 인연 완료
# 🎬 62/420 - 구미호뎐1938 완료
# 🎬 63/420 - 7인의 탈출 완료
# 🎬 187/420 - 랜드맨 완료
# 🎬 188/420 - 쇼군 완료
# 🎬 189/420 - '무죄추정' - Presumed Innocent 완료
# 🎬 190/420 - 침묵의 함대 완료
# 🎬 191/420 - 테스터먼트: 모세 이야기 완료
# 🎬 192/420 - 엘스베스 완료
# 🎬 193/420 - 젠틀맨: 더 시리즈 완료
# 🎬 194/420 - 아바타: 아앙의 전설 완료
# 🎬 195/420 - 더 펭귄 완료
# 🎬 196/420 - 배드 보이 완료
# 🎬 197/420 - 덱스터: 오리지널 씬 완료
# 🎬 198/420 - 괴물: 메넨데즈 형제 이야기 완료
# 🎬 199/420 - 듄: 프로퍼시 완료
# 🎬 200/420 - 크로스 완료
# 🎬 201/420 - Detective Van der Valk 완료
# 🎬 202/420 - 토킹 헤즈 완료
# 🎬 203/420 - 레이즈드 바이 울브스 완료
# 🎬 204/420 - Malory Towers 완료
# 🎬 205/420 - 런 완료
# 🎬 206/420 - 로드킬 완료
# 🎬 207/420 - 퀴즈 완료
# 🎬 208/420 - 갱스 오브 런던 완료
# 🎬 209/420 - 데브스 완료
# 🎬 210/420 - 더 그레이트 완료
# 🎬 211/420 - 화이트 하우스 팜 완료
# 🎬 212/420 - 미스 스칼렛의 사건 일지 완료
# 🎬 213/420 - 올 크리처스 그레이트 & 스몰 완료
# 🎬 214/420 - 코브라 완료
# 🎬 215/420 - Noughts + Crosses 완료
# 🎬 216/420 - 디 에디 완료
# 🎬 217/420 - 알렉스 라이더 완료
# 🎬 218/420 - 드라큘라 완료
# 🎬 219/420 - 아이 메이 디스트로이 유 완료
# 🎬 220/420 - 맥도날드 앤 도즈 완료
# 🎬 221/420 - 킨 완료
# 🎬 222/420 - 그레이스 완료
# 🎬 223/420 - 린다의 가장 완벽한 5개월 완료
# 🎬 224/420 - 봉제인형 살인사건 완료
# 🎬 225/420 - 이레귤러스 완료
# 🎬 226/420 - 더 롱 콜 완료
# 🎬 227/420 - 페이트: 윙스의 전설 완료
# 🎬 228/420 - Viewpoint 완료
# 🎬 229/420 - 메어 오브 이스트타운 완료
# 🎬 230/420 - 제로 칠 완료
# 🎬 231/420 - 무법자들 완료
# 🎬 232/420 - 주피터스 레거시 완료
# 🎬 233/420 - 도미나 완료
# 🎬 234/420 - Yr Amgueddfa 완료
# 🎬 235/420 - 80일간의 세계 일주 완료
# 🎬 236/420 - 인트루더 완료
# 🎬 237/420 - 더 서펀트 완료
# 🎬 238/420 - 비하인드 허 아이즈 완료
# 🎬 239/420 - Smother 완료
# 🎬 240/420 - 얼어붙은 바다 완료
# 🎬 241/420 - 61번가 완료
# 🎬 242/420 - Four Lives 완료
# 🎬 243/420 - The Tourist 완료
# 🎬 244/420 - Signora Volpe 완료
# 🎬 245/420 - 하트스토퍼 완료
# 🎬 246/420 - '배드 시스터즈' - Bad Sisters 완료
# 🎬 247/420 - 친구라는 이름의 가면 완료
# 🎬 248/420 - Riches 완료
# 🎬 249/420 - Sister Boniface Mysteries 완료
# 🎬 250/420 - Billy the Kid 완료
# 🎬 251/420 - 데블스 아워 완료
# 🎬 252/420 - 리뎀션 완료
# 🎬 253/420 - 라자루스 프로젝트 완료
# 🎬 254/420 - Screw 완료
# 🎬 255/420 - 미드위치 쿠쿠 완료
# 🎬 256/420 - 퀴어 애즈 포크 완료
# 🎬 257/420 - SAS: 로그 히어로즈 완료
# 🎬 258/420 - Harry Wild 완료
# 🎬 259/420 - 더 리스폰더 완료
# 🎬 260/420 - 용의자들 완료
# 🎬 261/420 - '리치 아메리칸 걸스' - The Buccaneers 완료
# 🎬 262/420 - NCIS: 시드니 완료
# 🎬 263/420 - Boat Story 완료
# 🎬 264/420 - Fifteen-Love 완료
# 🎬 265/420 - The Doll Factory 완료
# 🎬 266/420 - 어느 날 월터 형제들과 살게 됐다 완료
# 🎬 267/420 - The Following Events are Based on a Pack of Lies 완료
# 🎬 268/420 - '하이재킹' - Hijack 완료
# 🎬 269/420 - 리그 완료
# 🎬 270/420 - The Inheritance 완료
# 🎬 271/420 - 어큐즈드 완료
# 🎬 272/420 - The Good Ship Murder 완료
# 🎬 273/420 - 바디스 완료
# 🎬 274/420 - '신의 물방울' - Drops of God 완료
# 🎬 275/420 - 윈터 킹 완료
# 🎬 276/420 - Beyond Paradise 완료
# 🎬 277/420 - 파워 완료
# 🎬 278/420 - The Couple Next Door 완료
# 🎬 279/420 - A Kind of Spark 완료
# 🎬 280/420 - The Long Shadow 완료
# 🎬 281/420 - 데이 오브 더 자칼 완료
# 🎬 282/420 - 닥터 후 완료
# 🎬 283/420 - 노틸러스 완료
# 🎬 284/420 - Oderbruch 완료
# 🎬 285/420 - '디스클레이머' - Disclaimer 완료
# 🎬 286/420 - 워킹 데드: 더 원스 후 리브 완료
# 🎬 287/420 - Mr Loverman 완료
# 🎬 288/420 - Unsinkable 완료
# 🎬 289/420 - 베이비 레인디어 완료
# 🎬 290/420 - 삼체 완료
# 🎬 291/420 - Protection 완료
# 🎬 292/420 - '낯선 별자리' - Constellation 완료
# 🎬 293/420 - 스위트피 완료
# 🎬 294/420 - Dead Hot 완료
# 🎬 295/420 - 불면증 완료
# 🎬 296/420 - 로 앤 오더 토론토: 크리미널 인텐트 완료
# 🎬 297/420 - Joan 완료
# 🎬 298/420 - 슈퍼셀 완료
# 🎬 299/420 - 카오스 완료
# 🎬 300/420 - 아우슈비츠의 문신가 완료
# 🎬 301/420 - 마기아 레코드 마법소녀 마도카☆마기카 외전 완료
# 🎬 302/420 - 런웨이에서 웃어줘 완료
# 🎬 303/420 - 힐링 굿♡프리큐어 완료
# 🎬 304/420 - 아리스 인 보더랜드 완료
# 🎬 305/420 - 이케부쿠로 웨스트 게이트 파크 완료
# 🎬 306/420 - もっと！まじめにふまじめ かいけつゾロリ 완료
# 🎬 307/420 - エール 완료
# 🎬 308/420 - 여성향 게임의 파멸 플래그밖에 없는 악역 영애로 환생해버렸다... 완료
# 🎬 309/420 - 펫 완료
# 🎬 310/420 - 사랑은 계속될 거야 어디까지나 완료
# 🎬 311/420 - 나만이 17세인 세상에서 완료
# 🎬 312/420 - 사랑 없는 숲: 깊은 상처 완료
# 🎬 371/420 - 엔젤 플라이트: 국제영구송환사 완료
# 🎬 372/420 - 나의 행복한 결혼 완료
# 🎬 373/420 - 호리미야 -piece- 완료
# 🎬 374/420 - 너에게는 닿지 않아 완료
# 🎬 375/420 - 이혼 좀 합시다 완료
# 🎬 376/420 - 미타라이 가, 불타다 완료
# 🎬 377/420 - 제물공주와 짐승의 왕 완료
# 🎬 378/420 - 파라독스 라이브 THE ANIMATION 완료
# 🎬 379/420 - BanG Dream! It's MyGO!!!!! 완료
# 🎬 380/420 - 코타츠가 없는 집 완료
# 🎬 381/420 - 걸즈 밴드 크라이 완료
# 🎬 382/420 - 따스한 햇살의 소리를 들어라 완료
# 🎬 383/420 - 데드데드 데몬즈 디디디디 디스트럭션 완료
# 🎬 384/420 - 최애의 아이 완료
# 🎬 385/420 - おむすび 완료
# 🎬 386/420 - 나나레 하나나레 완료
# 🎬 387/420 - 신주쿠 야전병원 완료
# 🎬 388/420 - 체이서 게임 W 갑질 상사는 나의 전 여친 완료
# 🎬 389/420 - 늑대와 향신료 MERCHANT MEETS THE WISE WOLF 완료
# 🎬 390/420 - 푸른 상자 완료
# 🎬 391/420 - 루프 7회차 악역 영애는 적국에서 자유로운 신부 생활을 만끽한다 완료
# 🎬 392/420 - 언네임드 메모리 완료
# 🎬 393/420 - 마녀와 야수 완료
# 🎬 394/420 - 남편의 가정을 망가뜨릴 때까지 완료
# 🎬 395/420 - 지. -지구의 운동에 대하여- 완료
# 🎬 396/420 - パーフェクトプロポーズ 완료
# 🎬 397/420 - 날 가져요 ~추억편~ 완료
# 🎬 398/420 - '써니' - Sunny 완료
# 🎬 399/420 - 하늘을 건너는 교실 완료
# 🎬 400/420 - 라이징 임팩트 완료
# 🎬 401/420 - 걸즈 밴드 크라이 완료
# 🎬 402/420 - 따스한 햇살의 소리를 들어라 완료
# 🎬 403/420 - 데드데드 데몬즈 디디디디 디스트럭션 완료
# 🎬 404/420 - 최애의 아이 완료
# 🎬 405/420 - おむすび 완료
# 🎬 406/420 - 나나레 하나나레 완료
# 🎬 407/420 - 신주쿠 야전병원 완료
# 🎬 408/420 - 체이서 게임 W 갑질 상사는 나의 전 여친 완료
# 🎬 409/420 - 늑대와 향신료 MERCHANT MEETS THE WISE WOLF 완료
# 🎬 410/420 - 푸른 상자 완료
# 🎬 411/420 - 루프 7회차 악역 영애는 적국에서 자유로운 신부 생활을 만끽한다 완료
# 🎬 412/420 - 언네임드 메모리 완료
# 🎬 413/420 - 마녀와 야수 완료
# 🎬 414/420 - 남편의 가정을 망가뜨릴 때까지 완료
# 🎬 415/420 - 지. -지구의 운동에 대하여- 완료
# 🎬 416/420 - パーフェクトプロポーズ 완료
# 🎬 417/420 - 날 가져요 ~추억편~ 완료
# 🎬 418/420 - '써니' - Sunny 완료
# 🎬 419/420 - 하늘을 건너는 교실 완료
# 🎬 420/420 - 라이징 임팩트 완료
# ✅ 번역 완료: translated_dramas.csv 저장됨

# %%
#줄거리 병합
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv("translated_dramas.csv")

# '줄거리'와 'omdb_plot_ko'를 결합하여 'plot' 컬럼 생성
df["plot"] = df["줄거리"].fillna("") + " " + df["omdb_plot_ko"].fillna("")

# 결과를 같은 이름으로 저장 (덮어쓰기)
df.to_csv("translated_dramas_plot.csv", index=False, encoding="utf-8-sig")

# %%
#인물 분류
import pandas as pd

# 파일 불러오기
df = pd.read_csv("translated_dramas_plot.csv")

# 키워드 기반 중심인물 판단 함수
def check_keywords(text, keywords):
    if pd.isna(text):
        return False
    return any(keyword in text for keyword in keywords)

# ✅ 한글 키워드 정의
female_keywords = ["그녀", "여자", "여성", "소녀", "딸", "엄마", "어머니", "여신"]
male_keywords = ["그", "남자", "남성", "소년", "아들", "아빠", "아버지"]
lgbtq_keywords = ["게이", "레즈비언", "트랜스젠더", "퀴어", "성소수자", "논바이너리"]
disabled_keywords = ["장애인", "휠체어", "시각장애", "청각장애", "지체장애", "절단", "지적장애", "자폐"]
elderly_keywords = ["노인", "노령", "할아버지", "할머니", "은퇴한", "고령자"]

# Boolean 컬럼 생성
df["여성"] = df["plot"].apply(lambda x: check_keywords(x, female_keywords))
df["남성"] = df["plot"].apply(lambda x: check_keywords(x, male_keywords))
df["성소수자"] = df["plot"].apply(lambda x: check_keywords(x, lgbtq_keywords))
df["장애인"] = df["plot"].apply(lambda x: check_keywords(x, disabled_keywords))
df["노령층"] = df["plot"].apply(lambda x: check_keywords(x, elderly_keywords))

# 중심인물 요약 컬럼 생성
def get_main_character(row):
    tags = []
    for attr in ["여성", "남성", "성소수자", "장애인", "노령층"]:
        if row[attr]:
            tags.append(attr)
    return ", ".join(tags) if tags else "미분류"

df["main_character"] = df.apply(get_main_character, axis=1)

# 결과 저장
df.to_csv("translated_dramas_with_main_character.csv", index=False, encoding="utf-8-sig")
print("✅ 중심인물 분류 완료: translated_dramas_with_main_character.csv 저장됨")
# Out:
# ✅ 중심인물 분류 완료: translated_dramas_with_main_character.csv 저장됨

# %%
df['main_character'].value_counts()
# Out:
# main_character
# 남성              169
# 여성, 남성          139
# 미분류              78
# 여성               17
# 여성, 남성, 장애인       4
# 여성, 남성, 성소수자      3
# 여성, 남성, 노령층       2
# 남성, 노령층           2
# 남성, 성소수자          2
# 장애인               2
# 남성, 장애인           1
# 성소수자              1
# Name: count, dtype: int64

# %%
import requests
import time

# 🔐 TMDB API 키 불러오기
with open("tmdb_key.txt") as f:
    tmdb_key = f.read().strip()

# 🎬 주연 배우 이름 수집 함수 (영어 이름)
def get_main_cast_name(tmdb_id):
    url = f"https://api.themoviedb.org/3/tv/{tmdb_id}/credits?api_key={tmdb_key}&language=en-US"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if data["cast"]:
                return data["cast"][0]["name"]  # 첫 번째 인물 이름 (영어)
    except Exception as e:
        print(f"오류: {tmdb_id} → {e}")
    return None

# 🔄 cast 컬럼 추가
df["cast"] = df["tmdb_id"].apply(get_main_cast_name)
time.sleep(0.5)  # 호출 제한 보호용

# 💾 결과 저장
df.to_csv("translated_dramas_with_cast.csv", index=False, encoding="utf-8-sig")
print("✅ 'cast' 컬럼이 추가된 CSV 파일 저장 완료")
